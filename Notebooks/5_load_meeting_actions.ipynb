# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import polars as pl
import time
import pandas as pd
import numpy as np

# %% [markdown]
# ### Functions

# %%
def start_driver(url,add_cfa=False,options=None,current_driver=None):
    """
    Initializes a Chrome WebDriver instance and navigates to the specified URL.
    Args:
        url (str): The URL to navigate to after starting the WebDriver.
        add_cfa (bool, optional): If True, prepends "https://www.cfa.gov" to the URL. Defaults to False.
        options (webdriver.ChromeOptions, optional): Chrome options to configure the WebDriver. Defaults to None.
        current_driver (WebDriver, optional): An existing WebDriver instance to use instead of creating a new one. Defaults to None.
    Returns:
        WebDriver: An instance of the Chrome WebDriver.
    """
    if add_cfa:
        url = f"https://www.cfa.gov{url}"

    if current_driver is not None:
        current_driver.get(url)
        return current_driver
    else:
        driver = webdriver.Chrome(options=options)
        driver.get(url)
        return driver
    

def get_soup(driver, parser='html.parser'):
    """
    Returns BeautifulSoup object of the current page.
    """
    return BeautifulSoup(driver.page_source, parser)

# %% [markdown]
# ## Go to Individual Meeting Pages

# %%
# df.to_csv('meeting_info/meeting_links.csv', index=False)
df = pd.read_csv('../Data_Raw/meeting_info/meeting_links.csv')
df.head()
# Out:
#                  meeting_name_date  \
# 0   CFA Meeting — 21 November 2024
# 1    OGB Meeting — 7 November 2024
# 2    CFA Meeting — 17 October 2024
# 3     OGB Meeting — 2 October 2024
# 4  CFA Meeting — 19 September 2024
#
#                                         meeting_link meeting_type        date
# 0  /records-research/record-cfa-actions/2024/11/c...  CFA Meeting  2024-11-21
# 1  /records-research/record-cfa-actions/2024/11/o...  OGB Meeting  2024-11-07
# 2  /records-research/record-cfa-actions/2024/10/c...  CFA Meeting  2024-10-17
# 3  /records-research/record-cfa-actions/2024/10/o...  OGB Meeting  2024-10-02
# 4  /records-research/record-cfa-actions/2024/09/c...  CFA Meeting  2024-09-19

# %% [markdown]
# ### CFA MEETINGS

# %%
cfa_meeting = df['meeting_type'][0] == 'CFA Meeting'
url = df['meeting_link'][0]
print(f"CFA: {cfa_meeting}.\nLink: {url}")
# Out:
# CFA: True.
# Link: /records-research/record-cfa-actions/2024/11/cfa-meeting

# %%
driver = start_driver(url, add_cfa=True)
soup = get_soup(driver)

# %% [markdown]
# #### Get Old Georgetown Appendix

# %%
og_app_link = soup.find(
    'div', 
    {'class': 'field__items'} # All Content After Submission and Reviews
).find(
    'div',
    {'class': 'view-content views__content'} # Appendix 
).find(
    'div',
    {'class': 'views-field views-field-views-conditional-field-2'} # Old Georgetown Appendix
).find('a')['href']

og_app_link
# Out:
# '/records-research/record-cfa-actions/appendices/georgetown/45533'

# %%
start_driver(og_app_link, add_cfa=True, current_driver=driver)
soup = get_soup(driver)

# %%
# Get all the projects in the Georgetown appendix
appendix = [[h.find('header',{'class':'node__header node__header--teaser-view'}) # Project Number and Link
             ] + [
                 item for item in h.find_all('div',{'class':'field__item'}) # Get information for project part (eg HPA Number, Location, etc.)
                 ] for h in soup.find_all('div',{'class': 'rule-line rule-line--above u-leader-padding views-row views__row'})] # Iterate through each project

# %%
#Separate the links and text for some of the information
fixed_vals = []
for i in range(len(appendix)): # Iterate through each project
    record = []
    for info in appendix[i]:
        # Add info to the record (separates links)
        link = info.find('a')
        if link:
            record.append(link.text.strip())
            record.append(link['href'])
        else:
            record.append(info.text)
    fixed_vals.append(record)

# %%
# Put all project information into a dataframe
appendix_projects = pd.DataFrame(fixed_vals)

appendix_projects.rename(columns={0:'project_number',
                                  1:'project_link',
                                  2:'hpa_number',
                                  3:'location',
                                  4:'property',
                                  5:'description',
                                  6:'review_type',
                                  7:'previous_review_number',
                                  8:'previous_review_link',
                                  9:'recommendation'},inplace=True)

appendix_projects.head()
# Out:
#            0                                             1           2  \
# 0  OG 24-240  /records-research/project-search/og-24-240-1  HPA 24-305
# 1  OG 24-255  /records-research/project-search/og-24-255-2  HPA 24-320
# 2  OG 24-288  /records-research/project-search/og-24-288-3  HPA 24-365
# 3  OG 24-293  /records-research/project-search/og-24-293-3  HPA 24-370
# 4  OG 24-303  /records-research/project-search/og-24-303-0  HPA 24-391
#
#                                           3                      4  \
# 0          2728 O Street, NW\nUnited States              Residence
# 1          3306 O Street, NW\nUnited States              Residence
# 2          3700 O Street, NW\nUnited States  Georgetown University
# 3          3246 S Street, NW\nUnited States              Residence
# 4  1403 Wisconsin Avenue, NW\nUnited States             Commercial
#
#                                                    5        6          7  \
# 0                                      Rear addition  Concept  OG 24-240
# 1  New accessory structure with living space and ...  Concept  OG 24-255
# 2             Campus building signage and wayfinding  Concept  OG 24-288
# 3  Third story addition, renovation, landscape al...  Concept  OG 24-293
# 4                                      Signage - CVS   Permit  OG 24-303
#
#                                               8  \
# 0  /records-research/project-search/og-24-240-0
# 1  /records-research/project-search/og-24-255-1
# 2  /records-research/project-search/og-24-288-2
# 3  /records-research/project-search/og-24-293-2
# 4    /records-research/project-search/og-24-303
#
#                                                    9
# 0  No objection to concept design for a rear two-...
# 1  No objection to concept design for a new acces...
# 2  No objection to concept design for building si...
# 3  No objection to concept design for a third sto...
# 4  Returned without action. Permit application fo...

# %% [markdown]
# #### Another Example CFA Meeting (Get Letters on Main Page)

# %% [markdown]
# On this link, `'/records-research/record-cfa-actions/2017/09/cfa-meeting'`, we have OGB projects that are listed on this page with letters, along with the CFA projects. They are not in the appendix

# %%
df['meeting_link'].sample(n=1).iloc[0]
# Out:
# '/records-research/record-cfa-actions/2017/09/cfa-meeting'

# %%
start_driver('/records-research/record-cfa-actions/2017/09/cfa-meeting', add_cfa=True, current_driver=driver)
soup = get_soup(driver)

# %%
#Get relevant information for the items on the letters
def get_letter_info(soup):
    georgetown_projects = [
    x for x in soup.find_all(
        'div',
        {'class':'u-trailer rule-line rule-line--below rule-line--heavy views-row views__row'}
    ) if x.find('div',{'class':'field-content u-half-trailer u-text-bold'}).get_text(strip=True).startswith("OG")]

    project_info = []
    if len(georgetown_projects) > 0:
        for project in georgetown_projects:
            customer = project.find('h3').text # Project Customer
            pnum_hpa = project.find('div',{'class':"field-content u-half-trailer u-text-bold"}).text # project number and HPA
            description = project.find('p').text # Description of project
            p = [[x.text,x['href']] for x in project.find_all('a')]

            project_info.append([customer,pnum_hpa,description,p])
    return pd.DataFrame(project_info)

# %%
letters = get_letter_info(soup)
letters.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Find Sidebar to get Meeting Minutes

# %%
sidebar = soup.find('aside', {'class': 'l-page__sidebar l-page__sidebar--second'})
meeting_minutes_link = [x.find('div',class_=lambda x: "related-minutes" in x) for x in sidebar][0].find('a')['href']

# %% [markdown]
# #### **Functions**

# %%
def start_driver(url,add_cfa=False,options=None,current_driver=None):
    """
    Initializes a Chrome WebDriver instance and navigates to the specified URL.
    Args:
        url (str): The URL to navigate to after starting the WebDriver.
        add_cfa (bool, optional): If True, prepends "https://www.cfa.gov" to the URL. Defaults to False.
        options (webdriver.ChromeOptions, optional): Chrome options to configure the WebDriver. Defaults to None.
        current_driver (WebDriver, optional): An existing WebDriver instance to use instead of creating a new one. Defaults to None.
    Returns:
        WebDriver: An instance of the Chrome WebDriver.
    """
    if add_cfa:
        url = f"https://www.cfa.gov{url}"

    if current_driver is not None:
        current_driver.get(url)
        return current_driver
    else:
        driver = webdriver.Chrome(options=options)
        driver.get(url)
        return driver
    

def get_soup(driver, parser='html.parser'):
    """
    Returns BeautifulSoup object of the current page.
    """
    return BeautifulSoup(driver.page_source, parser)

# %%
def get_appendix(url,add_cfa=True,current_driver=None):
    """
    Extracts the Old Georgetown Appendix projects from the specified URL.
    Args:
        url (str): The URL to navigate to and extract the Old Georgetown Appendix projects from.
        add_cfa (bool, optional): If True, prepends "https://www.cfa.gov" to the URL. Defaults to True.
    Returns:
        pd.DataFrame: A Pandas DataFrame containing the extracted Old Georgetown Appendix projects with the following columns:
            - project_number (str): The project number. [e.g.: "OG 21-001"]
            - project_link (str): The URL link to the project. [e.g.: "/node/123456"]
            - hpa_number (str): The Historic Preservation Act (HPA) number. [e.g.: "HPA 21-001"]
            - location (str): The location of the project. [e.g.: "123 Main St NW"]
            - property (str): The property name. [e.g.: "The White House"]
            - description (str): A brief description of the project. [e.g.: "Renovation of the East Wing"]
            - review_type (str): The type of review. [e.g.: "Concept"]
            - previous_review_number (str): The previous review number. [e.g.: "OG 21-001"]
            - previous_review_link (str): The URL link to the previous review. [e.g.: "/node/123456"]
            - recommendation (str): The recommendation for the project. [e.g.: "Approve with conditions"]
    """
    driver = start_driver(url, add_cfa=add_cfa, current_driver=current_driver)
    soup = get_soup(driver)

    # Find all project nodes
    project_nodes = soup.select('div.rule-line.rule-line--above.u-leader-padding.views-row.views__row')
    projects = []

    for node in project_nodes:
        project = {}
        header = node.find('header', class_='node__header node__header--teaser-view')
        if header:
            project['project_number'] = header.text.strip()
            project['project_link'] = header.find('a')['href'] if header.find('a') else None

        project_information = node.find_all('div',{'class':['field__label','field__item']})
        cols = [col.text.strip().replace(' ','_').lower() for col in project_information if project_information.index(col) % 2 == 0] # Get the column names
        col_vals = [(col.find('a')['href'],col.text) if col.find('a') is not None else (col.text) for col in project_information if project_information.index(col) % 2 == 1] # Get the column values

        if col_vals:
            project.update(dict(zip(cols,col_vals)))
        project['meeting_link'] = url

        projects.append(project)

    return pd.DataFrame(projects)

def get_meeting_minute_link(soup,url):
    """
    Extracts the link to the meeting minutes from the specified URL.
    Args:
        url (str): The URL of the page to extract the meeting minutes link from.
        soup (BeautifulSoup): A BeautifulSoup object containing the HTML content to parse.
    Returns:
        pd.DataFrame: A Pandas DataFrame containing the page URL and meeting minutes link.
    """
    sidebar = soup.find('aside', {'class': 'l-page__sidebar l-page__sidebar--second'})
    
    try:
        meeting_minutes_link = [x.find('div',class_=lambda x: "related-minutes" in x) for x in sidebar][0].find('a')['href']
        return pd.DataFrame([url,meeting_minutes_link]).T
    except:
        print("No meeting minutes found.")
        return None

#Get relevant information for the items on the letters
def get_og_letters(soup):
    """
    Extracts information about Georgetown projects that start with "OG" from the provided BeautifulSoup object.
    Args:
        soup (BeautifulSoup): A BeautifulSoup object containing the HTML content to be parsed.
    Returns:
        pandas.DataFrame: A DataFrame containing the extracted project information with columns:
            - url: The URL of the project.
            - customer: The customer associated with the project.
            - pnum_hpa: The project number and HPA.
            - description: The description of the project.
            - p: A list of lists containing text and href attributes of all anchor tags within the project (get the letter and the previous review (if available)).
    """
    georgetown_projects = [
    x for x in soup.find_all(
        'div',
        {'class':'u-trailer rule-line rule-line--below rule-line--heavy views-row views__row'}
    ) if x.find('div',{'class':'field-content u-half-trailer u-text-bold'}).get_text(strip=True).startswith("OG")]

    if len(georgetown_projects) > 0:
        print(f"Found these georgetown letters: {georgetown_projects}")
        project_info = []
        for project in georgetown_projects:
            customer = project.find('h3').text # Project Customer
            pnum_hpa = project.find('div',{'class':"field-content u-half-trailer u-text-bold"}).text # project number and HPA
            description = project.find('p').text # Description of project
            p = [[x.text,x['href']] for x in project.find_all('a')]

            project_info.append([url,customer,pnum_hpa,description,p])
        return pd.DataFrame(project_info)
    else:
        print("No letters found.")
        return None

def query_meeting_page(meeting_url,add_cfa=True,current_driver=None):
    """
    Extracts the meeting minutes link from a CFA or OGB meeting page.
    Args:
        meeting_url (str): The URL of the CFA or OGB meeting page to query.
    Returns:
        pd.DataFrame: A tuple containing three elements:
            - minute_link (pd.DataFrame): A DataFrame containing the page URL and meeting minutes link.
            - letters (pd.DataFrame): A DataFrame containing the extracted project information.
            - og_appendix (pd.DataFrame): A DataFrame containing the extracted Old Georgetown Appendix projects.
    """
    driver = start_driver(meeting_url, add_cfa=add_cfa, current_driver=current_driver)
    soup = get_soup(driver)

    try:
        minute_link = get_meeting_minute_link(soup,meeting_url)
    except AttributeError as e:
        print(f"Minutes not found: {e}")
        minute_link = None
    
    try:
        letters = get_og_letters(soup)
    except AttributeError as e:
        print(f"Letters not found: {e}")
        letters = None

    try:
        appendix_link = soup.select_one(
            'div.field__items div.view-content.views__content div.views-field-views-conditional-field-2 a'
        )['href']
        og_appendix = get_appendix(appendix_link, add_cfa=True, current_driver=driver)
    except AttributeError as e:
        print(f"Appendix link not found: {e}")
        og_appendix = None

    return minute_link, letters, og_appendix

# %% [markdown]
# #### Get main page letters and meeting minute links, then old georgetown appendix

# %%
# 20 minutes 48 seconds
import os

# Directory to save results
output_dir = "../Data_Raw/meeting_info/cfa_meetings"
os.makedirs(output_dir, exist_ok=True)

# Initialize storage dictionaries
minute_links_dict = {}
letters_dict = {}
appendices_dict = {}

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--disable-gpu')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

driver = start_driver("https://www.cfa.gov", options=options)

# Iterate through URLs
for i, row in df.iterrows():
    if row['meeting_type'] == 'CFA Meeting':
        url = row['meeting_link']
        print(f"\nProcessing URL: {url}")
        try:
            # Call the query_meeting_page function
            minute_link, letters, appendix = query_meeting_page(url,current_driver=driver)
            
            # Save results to dictionaries
            if minute_link is not None:
                minute_links_dict[url] = minute_link
            
            if letters is not None:
                letters_dict[url] = letters
            
            if appendix is not None:
                appendices_dict[url] = appendix
            print(f"Successful.")
        except Exception as e:
            print(f"Error processing URL {url}: {e}")

# Convert dictionaries to DataFrames (optional, if you want a combined view)
minute_links_df = pd.concat(minute_links_dict.values(), keys=minute_links_dict.keys())
letters_df = pd.concat(letters_dict.values(), keys=letters_dict.keys())
appendices_df = pd.concat(appendices_dict.values(), keys=appendices_dict.keys())

# Save combined dataframes to CSV if needed
minute_links_df.to_csv(os.path.join(output_dir, "all_minute_links.csv"), index=False)
letters_df.to_csv(os.path.join(output_dir, "all_letters.csv"), index=False)
appendices_df.to_csv(os.path.join(output_dir, "all_appendices.csv"), index=False)
# Out:
# Processing URL: /records-research/record-cfa-actions/2024/11/cfa-meeting
# No meeting minutes found.
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/10/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/09/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/07/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/06/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/05/cfa-meeting
# Found these georgetown letters: [<div class="u-trailer rule-line rule-line--below rule-line--heavy views-row views__row"><div class="views-field views-field-field-owner-term"><h3 class="field-content u-text-uppercase u-text-tertiary u-half-trailer">D.C. Department of Buildings</h3></div><span class="views-field views-field-title"><div class="field-content u-half-trailer u-text-bold">OG 24-163 (HPA 24-192)</div></span><div class="views-field views-field-nothing"><span class="field-content"><p>Mixed-use, 1805 Wisconsin Avenue, NW.   Demolition of existing building; construction of nine row houses with ground floor retail. Concept.</p></span></div><div class="views-field views-field-nothing-1"><span class="field-content"><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div><div>Letter:</div><div><a href="/records-research/project-search/og-24-163-2">OG 24-163</a></div></div><div><div>Previous Review:</div><div><a href="/records-research/project-search/og-24-163-1" hreflang="und">OG 24-163</a></div></div><div><div>Report:</div><div><a href="/records-research/project-search/og-24-163-2">OG 24-163</a></div></div></div></span></div></div>]
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/04/cfa-meeting
# Found these georgetown letters: [<div class="u-trailer rule-line rule-line--below rule-line--heavy views-row views__row"><div class="views-field views-field-field-owner-term"><h3 class="field-content u-text-uppercase u-text-tertiary u-half-trailer">D.C. Department of Buildings</h3></div><span class="views-field views-field-title"><div class="field-content u-half-trailer u-text-bold">OG 23-257 (HPA 23-406)</div></span><div class="views-field views-field-nothing"><span class="field-content"><p>Commercial/Mixed-use, 1000 Thomas Jefferson Street, NW.   Modifications and additions to an existing office building for mixed use. Concept.</p></span></div><div class="views-field views-field-nothing-1"><span class="field-content"><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div><div>Letter:</div><div><a href="/records-research/project-search/og-23-257-5">OG 23-257</a></div></div><div><div>Previous Review:</div><div><a href="/records-research/project-search/og-23-257-4" hreflang="und">OG 23-257</a></div></div><div><div>Report:</div><div><a href="/records-research/project-search/og-23-257-5">OG 23-257</a></div></div></div></span></div><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div>Submitted Documents:<br/><span class="file file--mime-application-pdf file--application-pdf icon icon--left icon--file file icon--mime-application-pdf icon--application-pdf"><a href="/system/files/meeting-materials/4-OG%2023-257%268-1000%261050%20TJ%20Street%5B4-12%5D_pres.pdf" title="4-OG 23-257&amp;8-1000&amp;1050 TJ Street[4-12]_pres.pdf" type="application/pdf">1000 &amp; 1050 TJ Street presentation</a></span>
# </div></div></div>, <div class="u-trailer rule-line rule-line--below rule-line--heavy views-row views__row"><div class="views-field views-field-field-owner-term"><h3 class="field-content u-text-uppercase u-text-tertiary u-half-trailer">D.C. Department of Buildings</h3></div><span class="views-field views-field-title"><div class="field-content u-half-trailer u-text-bold">OG 23-258 (HPA 23-407)</div></span><div class="views-field views-field-nothing"><span class="field-content"><p>Commercial/Mixed-use, 1050 Thomas Jefferson Street, NW.   Modifications and additions to an existing office building for mixed use. Concept.</p></span></div><div class="views-field views-field-nothing-1"><span class="field-content"><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div><div>Letter:</div><div><a href="/records-research/project-search/og-23-258-5">OG 23-258</a></div></div><div><div>Previous Review:</div><div><a href="/records-research/project-search/og-23-258-4" hreflang="und">OG 23-258</a></div></div><div><div>Report:</div><div><a href="/records-research/project-search/og-23-258-5">OG 23-258</a></div></div></div></span></div><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div>Submitted Documents:<br/><span class="file file--mime-application-pdf file--application-pdf icon icon--left icon--file file icon--mime-application-pdf icon--application-pdf"><a href="/system/files/meeting-materials/4-OG%2023-257%268-1000%261050%20TJ%20Street%5B4-12%5D_pres.pdf" title="4-OG 23-257&amp;8-1000&amp;1050 TJ Street[4-12]_pres.pdf" type="application/pdf">1000 &amp; 1050 TJ Street presentation</a></span>
# </div></div></div>]
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/03/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/02/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/01/cfa-meeting
# No letters found.
# Error processing URL /records-research/record-cfa-actions/2024/01/cfa-meeting: 'NoneType' object is not subscriptable
#
# Processing URL: /records-research/record-cfa-actions/2023/11/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/10/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/09/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/07/cfa-meeting
# Found these georgetown letters: [<div class="u-trailer rule-line rule-line--below rule-line--heavy views-row views__row"><div class="views-field views-field-field-owner-term"><h3 class="field-content u-text-uppercase u-text-tertiary u-half-trailer">D.C. Department of Buildings</h3></div><span class="views-field views-field-title"><div class="field-content u-half-trailer u-text-bold">OG 23-199 (HPA 23-309)</div></span><div class="views-field views-field-nothing"><span class="field-content"><p>Commercial, 2900 - 2922 M Street, 1132 29th Street, NW.   New five-story building and alterations to historic rowhouses. Concept.</p></span></div><div class="views-field views-field-nothing-1"><span class="field-content"><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div><div>Letter:</div><div><a href="/records-research/project-search/og-23-199-2">OG 23-199</a></div></div><div><div>Previous Review:</div><div><a href="/records-research/project-search/og-23-199-1" hreflang="und">OG 23-199</a></div></div><div><div>Report:</div><div><a href="/records-research/project-search/og-23-199-2">OG 23-199</a></div></div></div></span></div><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div>Submitted Documents:<br/><span class="file file--mime-application-pdf file--application-pdf icon icon--left icon--file file icon--mime-application-pdf icon--application-pdf"><a href="/system/files/meeting-materials/8-OG-23-199-DOB-2900-M-St_pres.pdf" title="8-OG-23-199-DOB-2900-M-St_pres.pdf" type="application/pdf">2900 M St NW presentation</a></span>
# </div></div></div>]
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/06/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/05/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/04/cfa-meeting
# Found these georgetown letters: [<div class="u-trailer rule-line rule-line--below rule-line--heavy views-row views__row"><div class="views-field views-field-field-owner-term"><h3 class="field-content u-text-uppercase u-text-tertiary u-half-trailer">D.C. Department of Buildings</h3></div><span class="views-field views-field-title"><div class="field-content u-half-trailer u-text-bold">OG 23-163 (HPA 23-264)</div></span><div class="views-field views-field-nothing"><span class="field-content"><p>Dumbarton Oaks, 1703 32nd Street, NW.   New three-level building - Farrand House. Revised concept.</p></span></div><div class="views-field views-field-nothing-1"><span class="field-content"><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div><div>Letter:</div><div><a href="/records-research/project-search/og-23-163-0">OG 23-163</a></div></div><div><div>Previous Review:</div><div><a href="/records-research/project-search/og-23-163" hreflang="und">OG 23-163</a></div></div><div><div>Report:</div><div><a href="/records-research/project-search/og-23-163-0">OG 23-163</a></div></div></div></span></div><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div>Submitted Documents:<br/><span class="file file--mime-application-pdf file--application-pdf icon icon--left icon--file file icon--mime-application-pdf icon--application-pdf"><a href="/system/files/meeting-materials/8-OG%2023-163-DOB-1703-32nd-St_pres-sm.pdf" title="8-OG 23-163-DOB-1703-32nd-St_pres-sm.pdf" type="application/pdf">Dumbarton Oaks presentation</a></span>
# </div></div></div>]
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/03/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/02/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023
p></span></div><div class="views-field views-field-nothing-1"><span class="field-content"><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div><div>Letter:</div><div><a href="/records-research/project-search/og-03-108-0">OG 03-108</a></div></div><div><div>Previous Review:</div><div><a href="/records-research/project-search/og-03-108" hreflang="und">OG 03-108</a></div></div></div></span></div></div>, <div class="u-trailer rule-line rule-line--below rule-line--heavy views-row views__row"><div class="views-field views-field-field-owner-term"><h3 class="field-content u-text-uppercase u-text-tertiary u-half-trailer">D.C. Department of Consumer and Regulatory Affairs</h3></div><span class="views-field views-field-title"><div class="field-content u-half-trailer u-text-bold">OG 03-133 </div></span><div class="views-field views-field-nothing"><span class="field-content"><p>House of Sweden, 901 30th Street, NW.   New mixed-use building. Concept.</p></span></div><div class="views-field views-field-nothing-1"><span class="field-content"><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div><div>Letter:</div><div><a href="/records-research/project-search/og-03-133-0">OG 03-133</a></div></div><div><div>Previous Review:</div><div><a href="/records-research/project-search/og-03-108-0" hreflang="und">OG 03-108</a></div></div></div></span></div></div>]
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2003/03/cfa-meeting
# Found these georgetown letters: [<div class="u-trailer rule-line rule-line--below rule-line--heavy views-row views__row"><div class="views-field views-field-field-owner-term"><h3 class="field-content u-text-uppercase u-text-tertiary u-half-trailer">D.C. Department of Consumer and Regulatory Affairs</h3></div><span class="views-field views-field-title"><div class="field-content u-half-trailer u-text-bold">OG 03-108 </div></span><div class="views-field views-field-nothing"><span class="field-content"><p>House of Sweden, 901 30th Street, NW.   New building to house the Embassy of Sweden. Informational presentation on the concept selected from the design competition.</p></span></div><div class="views-field views-field-nothing-1"><span class="field-content"><div class="l-grid l-grid--equal-2 l-grid--condensed u-trailer"><div><div>Letter:</div><div><a href="/records-research/project-search/og-03-108">OG 03-108</a></div></div></div></span></div></div>]
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2003/02/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2003/01/cfa-meeting
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2002/11/cfa-meeting
# No meeting minutes found.
# No letters found.
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2002/10/cfa-meeting
# No meeting minutes found.
# No letters found.
# Successful.

# %% [markdown]
# ### OGB MEETINGS

# %%
i = 1
ogb_meeting = df['meeting_type'][i] == 'OGB Meeting'
url = df['meeting_link'][i]
print(f"OGB: {ogb_meeting}.\nLink: {url}")

#Additionally tested on i = 200 at url = /records-research/record-cfa-actions/2015/09/ogb-meeting
# Out:
# OGB: True.
# Link: /records-research/record-cfa-actions/2024/11/ogb-meeting

# %%
driver = start_driver(url, add_cfa=True)
soup = get_soup(driver)

# %% [markdown]
# #### Get links to consent, denial, other submissions calendars.

# %%
appendices = soup.find(
    'div', 
    {'class': 'field__items'} # All Content After Submission and Reviews
).find(
    'div',
    {'class': 'view-content views__content'} # Appendix 
)

# Extract the links for the Old Georgetown Appendix
decision_links = [
    appendices.find('div', {'class': f'views-field views-field-views-conditional-field{i}'}).find('a')['href']
    for i in ['', '-1', '-2']
]
decision_links
# Out:
# ['/records-research/record-cfa-actions/old-georgetown-board/consent-calendar/45542',
#  '/records-research/record-cfa-actions/old-georgetown-board/denial-calendar/45542',
#  '/records-research/record-cfa-actions/old-georgetown-board/other-submissions/45542']

# %% [markdown]
# #### Get letters information from the page.

# %%
def process_project(project):
    """
    Processes a project to extract URLs for "CFA Action" and "Previous Review".
    Args:
        project (BeautifulSoup object): A BeautifulSoup object representing the HTML content of a project.
    Returns:
        tuple: A tuple containing two elements:
            - cfa (str or None): The URL for "CFA Action" if found, otherwise None.
            - cfa_num (str or None): The project number for "CFA Action" if found, otherwise None.
            - prev (str or None): The URL for "Previous Review" if found, otherwise None.  
            - prev_num (str or None): The project number for "Previous Review" if found, otherwise None.
    """
    
    prev = None
    prev_num = None
    cfa = None
    cfa_num = None
    try:
        action = project.find('div', {'class': 'views-field views-field-nothing-1'}).get_text()
        if "CFA Action" in action:
            cfa = project.find('a', string="CFA Action")['href']
            cfa_num = project.find('a', string="CFA Action").get_text()
        if "Previous Review" in action:
            prev = project.find('a', string="Previous Review")['href']
            prev_num = project.find('a', string="Previous Review").get_text()
    except:
        None

    bottom = project.find_all('div', {'class': 'l-grid l-grid--equal-2 l-grid--condensed u-trailer'})
    
    for b in bottom:
        if "CFA Action" in b.get_text() and not cfa:
            i = str(b).index("CFA Action")
            s = BeautifulSoup(str(b)[i:], 'html.parser')
            cfa = s.find('a')['href']
            cfa_num = s.find('a').get_text()
        if "Previous Review" in b.get_text() and not prev:
            i = str(b).index("Previous Review")
            s = BeautifulSoup(str(b)[i:], 'html.parser')
            prev = s.find('a')['href']
            prev_num = s.find('a').get_text()
    
    return cfa, cfa_num, prev, prev_num

# %%
def og_project_reviews(soup):
    """
    Extracts project reviews from the Old Georgetown Appendix page.
    Args:
        soup (BeautifulSoup): A BeautifulSoup object containing the HTML content to parse.
    Returns:
        pd.DataFrame: A DataFrame containing the extracted project reviews with columns:
            - num_hpa (str): The HPA number.
            - location_desc (str): The location description.
            - cfa_action (str): The URL for the CFA action.
            - cfa_action_link (str): The project number for the CFA action.
            - prev_action (str): The URL for the previous action.
            - prev_action_link (str): The project number for the previous action.
            - documents (list): A list of document URLs.
    """
    georgetown_projects = [x for x in soup.find_all('div',
        {'class':'u-trailer rule-line rule-line--below rule-line--heavy views-row views__row'}
    )]

    project_info = []
    for project in georgetown_projects:
        num_hpa = project.find('div',{'class':'field-content u-half-trailer u-text-bold'}).text
        location_desc = project.find('div',{'class':'views-field views-field-nothing'}).text
        cfa_action, cfa_action_link, prev_action, prev_action_link = process_project(project)

        documents = [p.find('a')['href'] for p in project.find_all('span',
        {'class':'file file--mime-application-pdf file--application-pdf icon icon--left icon--file file icon--mime-application-pdf icon--application-pdf'})]

        project_info.append([
            num_hpa,location_desc,
            cfa_action, cfa_action_link, 
            prev_action, prev_action_link,
            documents])
        
    return pd.DataFrame(project_info)

# %% [markdown]
# #### Go through the consent, denial, and other pages. Previous function *get_appendix(appendix_url, add_cfa=True)* will work for this.
#
# Note: If you webscrape the latest ones, there will not be recommendations, but presentation material from the project such as slides. Get historic ones.

# %% [markdown]
# Be careful. I just found an appendix for https://www.cfa.gov/records-research/record-cfa-actions/appendices/georgetown/41523 on page https://www.cfa.gov/records-research/record-cfa-actions/2019/12/ogb-meeting

# %%
def query_ogb_meeting_page(meeting_url,add_cfa=True,current_driver=None):
    """
    Extracts the Old Georgetown Board (OGB) meeting minutes link and project reviews from the specified URL.
    Args:
        meeting_url (str): The URL of the OGB meeting page to query.
        add_cfa (bool, optional): If True, prepends "https://www.cfa.gov" to the URL. Defaults to True.
    Returns:
        pd.DataFrame: A tuple containing two elements:
            - minute_link (pd.DataFrame): A DataFrame containing the page URL and meeting minutes link.
            - project_reviews (pd.DataFrame): A DataFrame containing the extracted project reviews.
    """
    driver = start_driver(meeting_url, add_cfa=add_cfa, current_driver=current_driver)
    soup = get_soup(driver)

    #ADJUST THIS SO THAT IT CAN BE USED FOR WHEN THERE IS NO MEETING
    decision_links = [(soup.select_one(
        f'div.field__items div.view-content.views__content div.views-field-views-conditional-field{i}').text,
        soup.select_one(
        f'div.field__items div.view-content.views__content div.views-field-views-conditional-field{i} a')['href']) for i in ['','-1','-2'] if soup.select_one(
        f'div.field__items div.view-content.views__content div.views-field-views-conditional-field{i}')
    ]
    
    project_reviews = og_project_reviews(soup)

    try:
        consent = [decision_links[i] for i in range(len(decision_links)) if "Consent Calendar" in decision_links[i][0]][0][1]
        consents = get_appendix(consent, add_cfa=True, current_driver=driver)
    except:
        print(f"No consents for {meeting_url}")
        consents = None
    
    try:
        deny = [decision_links[i] for i in range(len(decision_links)) if "Denial Calendar" in decision_links[i][0]][0][1]
        denials = get_appendix(deny, add_cfa=True, current_driver=driver)
    except:
        print(f"No denials for {meeting_url}")
        denials = None

    try:
        other = [decision_links[i] for i in range(len(decision_links)) if "Other Submissions" in decision_links[i][0]][0][1]
        others = get_appendix(other, add_cfa=True, current_driver=driver)
    except:
        print(f"No other submissions for {meeting_url}")
        others = None



    return project_reviews, consents, denials, others

# %% [markdown]
# #### Iterate Through to Get Projects, Approval Status

# %%
#11 minutes 56 seconds
import os

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--disable-gpu')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# Directory to save results
output_dir = "meeting_info/ogb_meetings"
os.makedirs(output_dir, exist_ok=True)
consent_dir = os.path.join(output_dir, "consents")
denial_dir = os.path.join(output_dir, "denials")
other_dir = os.path.join(output_dir, "others")

os.makedirs(consent_dir, exist_ok=True)
os.makedirs(denial_dir, exist_ok=True)
os.makedirs(other_dir, exist_ok=True)

# Initialize storage dictionaries
reviews_dict = {}
consents_dict = {}
denials_dict = {}
others_dict = {}

driver = start_driver("https://www.cfa.gov", options=options)

# Iterate through URLs
for i, row in df.iterrows():
    if row['meeting_type'] == 'OGB Meeting':
        url = row['meeting_link']
        print(f"\nProcessing URL: {url}")
        try:
            # Call the query page function
            project_reviews, consents, denials, others = query_ogb_meeting_page(url,current_driver=driver)

            # Save results to dictionaries 
            if project_reviews is not None:
                reviews_dict[url] = project_reviews
            
            if consents is not None:
                consents_dict[url] = consents

            if denials is not None:
                denials_dict[url] = denials

            if others is not None:
                others_dict[url] = others

            print(f"Successful.")
        except Exception as e:
            print(f"Error processing URL {url}: {e}")

# Convert dictionaries to DataFrames (optional, if you want a combined view)
reviews_df = pd.concat(reviews_dict.values(), keys=reviews_dict.keys())
consents_df = pd.concat(consents_dict.values(), keys=consents_dict.keys())
denials_df = pd.concat(denials_dict.values(), keys=denials_dict.keys())
others_df = pd.concat(others_dict.values(), keys=others_dict.keys())

# Save combined dataframes to CSV if needed
reviews_df.to_csv(os.path.join(output_dir, "all_reviews.csv"), index=False)
consents_df.to_csv(os.path.join(consent_dir, "all_consents.csv"), index=False)
denials_df.to_csv(os.path.join(denial_dir, "all_denials.csv"), index=False)
others_df.to_csv(os.path.join(other_dir, "all_others.csv"), index=False)
# Out:
# Processing URL: /records-research/record-cfa-actions/2024/11/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/10/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/09/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/07/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/06/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/05/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/04/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/03/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2024/02/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/12/ogb-meeting
# No denials for /records-research/record-cfa-actions/2023/12/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/11/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/10/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/09/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/07/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/06/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/05/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/04/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/03/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2023/02/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2022/12/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2022/11/ogb-meeting
# No denials for /records-research/record-cfa-actions/2022/11/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2022/10/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2022/09/ogb-meeting
# No denials for /records-research/record-cfa-actions/2022/09/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2022/07/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2022/06/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2022/05/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2022/04/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2022/03/ogb-meeting
# No denials for /records-research/record-cfa-actions/2022/03/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2022/02/ogb-meeting
# No denials for /records-research/record-cfa-actions/2022/02/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2021/12/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2021/11/ogb-meeting
# No denials for /records-research/record-cfa-actions/2021/11/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2021/10/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2021/09/ogb-meeting
# No denials for /records-research/record-cfa-actions/2021/09/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2021/07/ogb-meeting
# No denials for /records-research/record-cfa-actions/2021/07/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2021/06/ogb-meeting
# No denials for /records-research/record-cfa-actions/2021/06/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2021/05/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2021/04/ogb-meeting
# No denials for /records-research/record-cfa-actions/2021/04/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2021/03/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2021/02/ogb-meeting
# No denials for /records-research/record-cfa-actions/2021/02/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2021/01/ogb-meeting
# No denials for /records-research/record-cfa-actions/2021/01/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2020/12/ogb-meeting
# No denials for /records-research/record-cfa-actions/2020/12/ogb-meeting
# No other submissions for /records-research/record-cfa-actions/2020/12/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2020/11/ogb-meeting
# No denials for /records-research/record-cfa-actions/2020/11/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2020/10/ogb-meeting
# No denials for /records-research/record-cfa-actions/2020/10/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2020/09/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2020/07/ogb-meeting
# No denials for /records-research/record-cfa-actions/2020/07/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2020/06/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2020/05/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2020/04/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2020/03/ogb-meeting
# No denials for /records-research/record-cfa-actions/2020/03/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2020/02/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2019/12/ogb-meeting
# No denials for /records-research/record-cfa-actions/2019/12/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2019/11/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2019/10/ogb-meeting
# No denials for /records-research/record-cfa-actions/2019/10/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2019/09/ogb-meeting
# No denials for /records-research/record-cfa-actions/2019/09/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2019/07/ogb-meeting
# No denials for /records-research/record-cfa-actions/2019/07/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2019/06/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2019/05/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2019/04/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2019/03/ogb-meeting
# No denials for /records-research/record-cfa-actions/2019/03/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2019/02/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2019/01/ogb-meeting
# No consents for /records-research/record-cfa-actions/2019/01/ogb-meeting
# No denials for /records-research/record-cfa-actions/2019/01/ogb-meeting
# No other submissions for /records-research/record-cfa-actions/2019/01/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2018/12/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2018/11/ogb-meeting
# No denials for /records-research/record-cfa-actions/2018/11/ogb-meeting
# No other submissions for /records-research/record-cfa-actions/2018/11/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2018/10/ogb-meeting
# No denials for /records-research/record-cfa-actions/2018/10/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2018/09/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2018/07/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2018/06/ogb-meeting
# No denials for /records-research/record-cfa-actions/2018/06/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2018/05/ogb-meeting
# No denials for /records-research/record-cfa-actions/2018/05/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2018/04/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2018/03/ogb-meeting
# No denials for /records-research/record-cfa-actions/2018/03/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2018/02/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2018/01/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2017/12/ogb-meeting
# No denials for /records-research/record-cfa-actions/2017/12/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2017/11/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2017/10/ogb-meeting
# No denials for /records-research/record-cfa-actions/2017/10/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2017/09/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2017/07/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2017/06/ogb-meeting
# No denials for /records-research/record-cfa-actions/2017/06/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2017/05/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2017/04/ogb-meeting
# No denials for /records-research/record-cfa-actions/2017/04/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2017/03/ogb-meeting
# No denials for /records-research/record-cfa-actions/2017/03/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2017/02/ogb-meeting
# No other submissions for /records-research/record-cfa-actions/2017/02/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2017/01/ogb-meeting
# No denials for /records-research/record-cfa-actions/2017/01/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2016/12/ogb-meeting
# No denials for /records-research/record-cfa-actions/2016/12/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2016/11/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2016/10/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2016/09/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2016/07/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2016/06/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2016/05/ogb-meeting
# No denials for /records-research/record-cfa-actions/2016/05/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2016/04/ogb-meeting
# No denials for /records-research/record-cfa-actions/2016/04/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2016/03/ogb-meeting
# No denials for /records-research/record-cfa-actions/2016/03/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2016/02/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2016/01/ogb-meeting
# No denials for /records-research/record-cfa-actions/2016/01/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2015/12/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2015/11/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2015/10/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2015/09/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2015/07/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2015/06/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2015/05/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2015/04/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2015/03/ogb-meeting
# No denials for /records-research/record-cfa-actions/2015/03/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2015/02/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2015/01/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2014/12/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2014/11/ogb-meeting
# No denials for /records-research/record-cfa-actions/2014/11/ogb-meeting
# Successful.
#
# Processing URL: /records-research/record-cfa-actions/2014/10/ogb-meeting
# Successful.

# %%
consents_df.to_csv(os.path.join(consent_dir, "all_consents.csv"), index=False)
denials_df.to_csv(os.path.join(denial_dir, "all_denials.csv"), index=False)
others_df.to_csv(os.path.join(other_dir, "all_others.csv"), index=False)
