# %%
import os
import pandas as pd
import numpy as np
import re
from geopy.geocoders import Nominatim

# %% [markdown]
# ### Load In the File and Initially Examine

# %%
# Define the folder containing the parquet files
folder_path = '../Data_Raw/project_tables'

# List all parquet files in the folder
parquet_files = [f for f in os.listdir(folder_path) if f.endswith('.parquet')]

# Read and concatenate all parquet files into one dataframe
df = pd.concat([pd.read_parquet(os.path.join(folder_path, f)) for f in parquet_files], ignore_index=True)

# Display the first few rows of the combined dataframe
df.head()
# Out:
#   project_number                                  project_link project_type  \
# 0      OG 25-038  /records-research/project-search/og-25-038-0   Commercial
# 1      OG 25-037  /records-research/project-search/og-25-037-0   Georgetown
# 2      OG 25-036  /records-research/project-search/og-25-036-0    Residence
# 3      OG 25-034  /records-research/project-search/og-25-034-0    Residence
# 4      OG 25-033  /records-research/project-search/og-25-033-0  Residential
#
#                                project_location  \
# 0  [1023 - 1029 31st Street, NW, United States]
# 1            [3700 O Street, NW, United States]
# 2            [3321 Q Street, NW, United States]
# 3            [3306 O Street, NW, United States]
# 4            [3114 R Street, NW, United States]
#
#                         project_description         last_reviewed  \
# 0                        Sign - Canal House  2024-11-21T12:00:00Z
# 1                         Shaw Field lights  2024-11-21T12:00:00Z
# 2      Egress window well on west elevation  2024-11-21T12:00:00Z
# 3             Shutter and door replacements  2024-11-21T12:00:00Z
# 4  Landscape alterations and stair revision  2024-11-21T12:00:00Z
#
#                                last_reviewed_meeting  \
# 0  /records-research/record-cfa-actions/2024/11/c...
# 1  /records-research/record-cfa-actions/2024/11/c...
# 2  /records-research/record-cfa-actions/2024/11/c...
# 3  /records-research/record-cfa-actions/2024/11/c...
# 4  /records-research/record-cfa-actions/2024/11/c...
#
#                    review_type
# 0  (CFA Meeting - OG Appendix)
# 1  (CFA Meeting - OG Appendix)
# 2  (CFA Meeting - OG Appendix)
# 3  (CFA Meeting - OG Appendix)
# 4  (CFA Meeting - OG Appendix)

# %%
df['project_location_clean'] = df['project_location'].apply(
    lambda x: ' '.join(
        [location.lower().replace(' - ','-').strip() for location in x if location.lower() != "united states"]
        )
    ).str.replace(', ',' ').str.replace(' washington dc','').str.replace(' st.',' street').str.replace('½','1/2').str.replace('−','-')

df.drop(columns=['project_location'], inplace=True)

# %%
og = df[df['project_number'].apply(lambda x: x.split()[0] == 'OG')]

# %% [markdown]
# #### Check for Duplicate Addresses per Project

# %% [markdown]
# Are there any duplicate project locations per project number?

# %%
duplicate_addresses = og.groupby(['project_number'])['project_location_clean'].unique().apply(len).sort_values(ascending=False)
duplicate_addresses = duplicate_addresses[duplicate_addresses > 1].index
len(duplicate_addresses)
# Out:
# 32

# %% [markdown]
# Seeing which ones have multiple addresses associated with the project

# %%
for a in duplicate_addresses:
    print(a)
    print(og[og['project_number'] == a]['project_location_clean'].unique())
    print('\n')
# Out:
# OG 24-163
# ['1805 wisconsin avenue nw' '1803 wisconsin avenue nw']
#
#
# OG 12-337
# ['3220 grace street nw'
#  '3220 grace street nw (also known as 3240 grace street nw)']
#
#
# OG 15-165
# ['3271-3273 m street nw' '3271 and 3273 m street nw']
#
#
# OG 24-194
# ['adjacent to 3419 r street nw' 'tbd']
#
#
# OG 24-253
# ['tbd (adjacent to 3419 r street nw)' 'tbd']
#
#
# OG 15-170
# ['2522 q street nw' '2722 q street nw']
#
#
# OG 18-100
# ['3700 o street nw' '3700 o street nw-white gravenor hall']
#
#
# OG 23-317
# ['1312 30th street nw' '2915 q street nw']
#
#
# OG 07-127
# ['1645 31st street nw' 'single-family residence 1645 31st street nw']
#
#
# OG 14-369
# ['3252 jones court nw' '3252 jones court']
#
#
# OG 12-145
# ['3138 p street nw' '13138 p street nw']
#
#
# OG 16-194
# ['1301-29 37th street 3614-22 o street 3615-25 n street nw'
#  '1301-1329 37th 3614-3622 o 3615-3625 n streets nw']
#
#
# OG 22-177
# ['3299 k (water) street nw' '3299 water street nw']
#
#
# OG 22-069
# ['3401 water street nw' '2909 m street nw']
#
#
# OG 14-235
# ['3330 m street nw (rear)' '3330 m street nw']
#
#
# OG 24-342
# ['1023-29 31st street nw' '1023-31 31st street nw']
#
#
# OG 17-137
# ['1246-1250 27th street nw' '1210-1214 28th street nw']
#
#
# OG 17-146
# ['1051-1055 29th street nw' '1051 29th street nw']
#
#
# OG 20-227
# ['' '1267 wisconsin avenue nw']
#
#
# OG 17-257
# ['1101 30th street nw' '1728 wisconsin avenue nw']
#
#
# OG 23-347
# ['3325 r street nw' '1238 wisconsin avenue nw']
#
#
# OG 15-290
# ['1242 29th street nw' '1242 29th street']
#
#
# OG 17-039
# ['1032-1034 33rd street nw' '3304 n street nw']
#
#
# OG 08-011
# ['georgetown park (shopping mall) 3270 m street nw (square 1200 lot 67)'
#  'georgetown park (shopping mall) 3270 m street nw']
#
#
# OG 15-048
# ['1525 wisconsin avenue nw' '15 25 wisconsin avenue nw']
#
#
# OG 24-066
# ['1073 wisconsin avenue nw' '1073 wisconsin avenue nw (blues alley)']
#
#
# OG 21-009
# ['sites in georgetown' '']
#
#
# OG 03-284
# ['e. chamberlain residence 2720 o street nw' '2720 o street nw']
#
#
# OG 04-197
# ['house of sweden 901 30th street nw' '901 30th street nw']
#
#
# OG 20-160
# ['3000 m street nw' '3000 m street nwn']
#
#
# OG 20-062
# ['1070 wisconsin avenue' '1070 wisconsin avenue nw']
#
#
# OG 19-005
# ['3700 o street nw' '3700 o street nw-white gravenor hall']

# %% [markdown]
# #### Map the Locations

# %% [markdown]
# Convert the projects into project locations

# %%
og.head(3)
# Out:
#   project_number                                  project_link project_type  \
# 0      OG 25-038  /records-research/project-search/og-25-038-0   Commercial
# 1      OG 25-037  /records-research/project-search/og-25-037-0   Georgetown
# 2      OG 25-036  /records-research/project-search/og-25-036-0    Residence
#
#                     project_description         last_reviewed  \
# 0                    Sign - Canal House  2024-11-21T12:00:00Z
# 1                     Shaw Field lights  2024-11-21T12:00:00Z
# 2  Egress window well on west elevation  2024-11-21T12:00:00Z
#
#                                last_reviewed_meeting  \
# 0  /records-research/record-cfa-actions/2024/11/c...
# 1  /records-research/record-cfa-actions/2024/11/c...
# 2  /records-research/record-cfa-actions/2024/11/c...
#
#                    review_type    project_location_clean
# 0  (CFA Meeting - OG Appendix)  1023-1029 31st street nw
# 1  (CFA Meeting - OG Appendix)          3700 o street nw
# 2  (CFA Meeting - OG Appendix)          3321 q street nw

# %%
og[og['project_location_clean'].str.contains('-')]
# Out:
#       project_number                                  project_link  \
# 0          OG 25-038  /records-research/project-search/og-25-038-0
# 25         OG 24-361  /records-research/project-search/og-24-361-1
# 28         OG 24-342  /records-research/project-search/og-24-342-1
# 30         OG 24-337  /records-research/project-search/og-24-337-0
# 94         OG 25-038    /records-research/project-search/og-25-038
# ...              ...                                           ...
# 18569      OG 03-142    /records-research/project-search/og-03-142
# 18573      OG 03-138    /records-research/project-search/og-03-138
# 18712      OG 03-051    /records-research/project-search/og-03-051
# 18715      OG 03-034    /records-research/project-search/og-03-034
# 18738      OG 03-029    /records-research/project-search/og-03-029
#
#           project_type                                project_description  \
# 0           Commercial                                 Sign - Canal House
# 25          Commercial  New storefront, signage, entrances, and painti...
# 28          Commercial                              Signage - Canal House
# 30          Commercial           New gate, fenestration alterations, sign
# 94          Commercial                                            Signage
# ...                ...                                                ...
# 18569  Location1235-37                Replacement windows in front facade
# 18573            Eagle  Alterations to storefronts for new building-re...
# 18712        Residence                New board fences and repair of gate
# 18715            Eagle        Alterations to storefronts for new building
# 18738            Canal  Alterations to storefront and courtyard, signb...
#
#               last_reviewed  \
# 0      2024-11-21T12:00:00Z
# 25     2024-11-21T12:00:00Z
# 28     2024-11-21T12:00:00Z
# 30     2024-11-21T12:00:00Z
# 94     2024-11-07T12:00:00Z
# ...                     ...
# 18569  2003-04-22T12:00:00Z
# 18573  2003-04-22T12:00:00Z
# 18712  2003-01-16T12:00:00Z
# 18715  2003-01-16T12:00:00Z
# 18738  2002-12-19T12:00:00Z
#
#                                    last_reviewed_meeting  \
# 0      /records-research/record-cfa-actions/2024/11/c...
# 25     /records-research/record-cfa-actions/2024/11/c...
# 28     /records-research/record-cfa-actions/2024/11/c...
# 30     /records-research/record-cfa-actions/2024/11/c...
# 94     /records-research/record-cfa-actions/2024/11/o...
# ...                                                  ...
# 18569  /records-research/record-cfa-actions/2003/04/c...
# 18573  /records-research/record-cfa-actions/2003/04/c...
# 18712  /records-research/record-cfa-actions/2003/01/c...
# 18715  /records-research/record-cfa-actions/2003/01/c...
# 18738  /records-research/record-cfa-actions/2002/12/c...
#
#                             review_type       project_location_clean
# 0           (CFA Meeting - OG Appendix)     1023-1029 31st street nw
# 25          (CFA Meeting - OG Appendix)        3233-3235 m street nw
# 28          (CFA Meeting - OG Appendix)       1023-29 31st street nw
# 30          (CFA Meeting - OG Appendix)     1220-1236 31st street nw
# 94     (OGB Meeting - Consent Calendar)     1023-1029 31st street nw
# ...                                 ...                          ...
# 18569       (CFA Meeting - OG Appendix)  1235-37 wisconsin avenue nw
# 18573       (CFA Meeting - OG Appendix)          3331-47 m street nw
# 18712       (CFA Meeting - OG Appendix)  1528 -30 -32 34th street nw
# 18715       (CFA Meeting - OG Appendix)        3331-3347 m street nw
# 18738       (CFA Meeting - OG Appendix)          3110-12 m street nw
#
# [413 rows x 8 columns]

# %%
def clean_dashes_address(address):
    # Remove digits with a dash in front of them
    cleaned_address = re.sub(r'-\d+', '', address)
    # Remove a dash followed by a single letter and a space
    cleaned_address = re.sub(r'-[a-zA-Z] ', '', cleaned_address)
    # Remove any extra spaces
    cleaned_address = re.sub(r'\s+', ' ', cleaned_address).strip()

    # Find the index of the first digit in the address
    first_digit_index = re.search(r'\d', cleaned_address)
    if first_digit_index:
        cleaned_address = cleaned_address[first_digit_index.start():]
    return cleaned_address

# %%
og['project_location_preload_geolocator'] = og['project_location_clean'].apply(clean_dashes_address)
og['project_location_preload_geolocator'] = og['project_location_preload_geolocator'] + ", washington, district of columbia"

# %%
# Initialize geocoder
geolocator = Nominatim(user_agent="geoapi")

def get_coordinates(address):
    try:
        # Geocode the address
        location = geolocator.geocode(address, timeout=15)
        if location:
            return location
        else:
            return None
    except Exception as e:
        print(f"Error geocoding {address}: {e}")
        return None

# %%
#100m 46.1s
for i in range(0, len(og), 100):
    print(f"Processing rows {i} to {i+100}")
    og.loc[i:i+100,'Coordinates'] = og['project_location_preload_geolocator'].iloc[i:i+100].apply(get_coordinates)
# Out:
# Processing rows 0 to 100
# C:\Users\finnr\AppData\Local\Temp\ipykernel_23496\143738719.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   og.loc[i:i+100,'Coordinates'] = og['project_location_preload_geolocator'].iloc[i:i+100].apply(get_coordinates)
# Processing rows 100 to 200
# Processing rows 200 to 300
# Processing rows 300 to 400
# Processing rows 400 to 500
# Processing rows 500 to 600
# Processing rows 600 to 700
# Processing rows 700 to 800
# Processing rows 800 to 900
# Processing rows 900 to 1000
# Processing rows 1000 to 1100
# Processing rows 1100 to 1200
# Processing rows 1200 to 1300
# Processing rows 1300 to 1400
# Processing rows 1400 to 1500
# Processing rows 1500 to 1600
# Processing rows 1600 to 1700
# Processing rows 1700 to 1800
# Processing rows 1800 to 1900
# Processing rows 1900 to 2000
# Processing rows 2000 to 2100
# Processing rows 2100 to 2200
# Processing rows 2200 to 2300
# Processing rows 2300 to 2400
# Processing rows 2400 to 2500
# Processing rows 2500 to 2600
# Processing rows 2600 to 2700
# Processing rows 2700 to 2800
# Processing rows 2800 to 2900
# Processing rows 2900 to 3000
# Processing rows 3000 to 3100
# Processing rows 3100 to 3200
# Processing rows 3200 to 3300
# Processing rows 3300 to 3400
# Processing rows 3400 to 3500
# Processing rows 3500 to 3600
# Processing rows 3600 to 3700
# Processing rows 3700 to 3800
# Processing rows 3800 to 3900
# Processing rows 3900 to 4000
# Processing rows 4000 to 4100
# Processing rows 4100 to 4200
# Processing rows 4200 to 4300
# Processing rows 4300 to 4400
# Processing rows 4400 to 4500
# Processing rows 4500 to 4600
# Processing rows 4600 to 4700
# Processing rows 4700 to 4800
# Processing rows 4800 to 4900
# Processing rows 4900 to 5000
# Processing rows 5000 to 5100
# Processing rows 5100 to 5200
# Processing rows 5200 to 5300
# Processing rows 5300 to 5400
# Processing rows 5400 to 5500
# Processing rows 5500 to 5600
# Processing rows 5600 to 5700
# Processing rows 5700 to 5800
# Processing rows 5800 to 5900
# Processing rows 5900 to 6000
# Processing rows 6000 to 6100
# Processing rows 6100 to 6200
# Processing rows 6200 to 6300
# Processing rows 6300 to 6400
# Processing rows 6400 to 6500
# Processing rows 6500 to 6600
# Processing rows 6600 to 6700
# Processing rows 6700 to 6800
# Processing rows 6800 to 6900
# Processing rows 6900 to 7000
# Processing rows 7000 to 7100
# Processing rows 7100 to 7200
# Processing rows 7200 to 7300
# Processing rows 7300 to 7400
# Processing rows 7400 to 7500
# Processing rows 7500 to 7600
# Processing rows 7600 to 7700
# Processing rows 7700 to 7800
# Processing rows 7800 to 7900
# Processing rows 7900 to 8000
# Processing rows 8000 to 8100
# Processing rows 8100 to 8200
# Processing rows 8200 to 8300
# Processing rows 8300 to 8400
# Processing rows 8400 to 8500
# Processing rows 8500 to 8600
# Processing rows 8600 to 8700
# Processing rows 8700 to 8800
# Processing rows 8800 to 8900
# Processing rows 8900 to 9000
# Processing rows 9000 to 9100
# Processing rows 9100 to 9200
# Processing rows 9200 to 9300
# Processing rows 9300 to 9400
# Processing rows 9400 to 9500
# Processing rows 9500 to 9600
# Processing rows 9600 to 9700
# Processing rows 9700 to 9800
# Processing rows 9800 to 9900
# Processing rows 9900 to 10000
# Processing rows 10000 to 10100
# Processing rows 10100 to 10200
# Processing rows 10200 to 10300
# Processing rows 10300 to 10400
# Processing rows 10400 to 10500
# Processing rows 10500 to 10600
# Processing rows 10600 to 10700
# Processing rows 10700 to 10800
# Processing rows 10800 to 10900
# Processing rows 10900 to 11000
# Processing rows 11000 to 11100
# Processing rows 11100 to 11200
# Processing rows 11200 to 11300
# Processing rows 11300 to 11400
# Processing rows 11400 to 11500

# %%
t = og.fillna('project_location_preload_geolocator')['Coordinates']
for i in range(0, len(og), 100):
    print(f"Processing rows {i} to {i+100}")
    og.iloc[i:i+100,-1] = t.iloc[i:i+100].apply(get_coordinates)
# Out:
# Processing rows 0 to 100
# Processing rows 100 to 200
# Processing rows 200 to 300
# Processing rows 300 to 400
# Processing rows 400 to 500
# Processing rows 500 to 600
# Processing rows 600 to 700
# Processing rows 700 to 800
# Processing rows 800 to 900
# Processing rows 900 to 1000
# Processing rows 1000 to 1100
# Processing rows 1100 to 1200
# Processing rows 1200 to 1300
# Processing rows 1300 to 1400
# Processing rows 1400 to 1500
# Processing rows 1500 to 1600
# Processing rows 1600 to 1700
# Processing rows 1700 to 1800
# Processing rows 1800 to 1900
# Processing rows 1900 to 2000
# Processing rows 2000 to 2100
# Processing rows 2100 to 2200
# Processing rows 2200 to 2300
# Processing rows 2300 to 2400
# Processing rows 2400 to 2500
# Processing rows 2500 to 2600
# Processing rows 2600 to 2700
# Processing rows 2700 to 2800
# Processing rows 2800 to 2900
# Processing rows 2900 to 3000
# Processing rows 3000 to 3100
# Processing rows 3100 to 3200
# Processing rows 3200 to 3300
# Processing rows 3300 to 3400
# Processing rows 3400 to 3500
# Processing rows 3500 to 3600
# Processing rows 3600 to 3700
# Processing rows 3700 to 3800
# Processing rows 3800 to 3900
# Processing rows 3900 to 4000
# Processing rows 4000 to 4100
# Processing rows 4100 to 4200
# Processing rows 4200 to 4300
# Processing rows 4300 to 4400
# Processing rows 4400 to 4500
# Processing rows 4500 to 4600
# Processing rows 4600 to 4700
# Processing rows 4700 to 4800
# Processing rows 4800 to 4900
# Processing rows 4900 to 5000
# Processing rows 5000 to 5100
# Processing rows 5100 to 5200
# Processing rows 5200 to 5300
# Processing rows 5300 to 5400
# Processing rows 5400 to 5500
# Processing rows 5500 to 5600
# Processing rows 5600 to 5700
# Processing rows 5700 to 5800
# Processing rows 5800 to 5900
# Processing rows 5900 to 6000
# Processing rows 6000 to 6100
# Processing rows 6100 to 6200
# Processing rows 6200 to 6300
# Processing rows 6300 to 6400
# Processing rows 6400 to 6500
# Processing rows 6500 to 6600
# Processing rows 6600 to 6700
# Processing rows 6700 to 6800
# Processing rows 6800 to 6900
# Processing rows 6900 to 7000
# Processing rows 7000 to 7100
# Processing rows 7100 to 7200
# Processing rows 7200 to 7300
# Processing rows 7300 to 7400
# Processing rows 7400 to 7500
# Processing rows 7500 to 7600
# Processing rows 7600 to 7700
# Processing rows 7700 to 7800
# Processing rows 7800 to 7900
# Processing rows 7900 to 8000
# Processing rows 8000 to 8100
# Processing rows 8100 to 8200
# Processing rows 8200 to 8300
# Processing rows 8300 to 8400
# Processing rows 8400 to 8500
# Processing rows 8500 to 8600
# Processing rows 8600 to 8700
# Processing rows 8700 to 8800
# Processing rows 8800 to 8900
# Processing rows 8900 to 9000
# Processing rows 9000 to 9100
# Processing rows 9100 to 9200
# Processing rows 9200 to 9300
# Processing rows 9300 to 9400
# Processing rows 9400 to 9500
# Processing rows 9500 to 9600
# Processing rows 9600 to 9700
# Processing rows 9700 to 9800
# Processing rows 9800 to 9900
# Processing rows 9900 to 10000
# Processing rows 10000 to 10100
# Processing rows 10100 to 10200
# Processing rows 10200 to 10300
# Processing rows 10300 to 10400
# Processing rows 10400 to 10500
# Processing rows 10500 to 10600
# Processing rows 10600 to 10700
# Processing rows 10700 to 10800
# Processing rows 10800 to 10900
# Processing rows 10900 to 11000
# Processing rows 11000 to 11100
# Processing rows 11100 to 11200
# Processing rows 11200 to 11300
# Processing rows 11300 to 11400
# Processing rows 11400 to 11500

# %%
for i in range(700, len(og), 100):
    print(f"Processing rows {i} to {i+100}")
    og.iloc[i:i+100,-1] = og['project_location_preload_geolocator'].iloc[i:i+100].apply(get_coordinates)
# Out:
# Processing rows 700 to 800
# Processing rows 800 to 900
# Processing rows 900 to 1000
# Processing rows 1000 to 1100
# Processing rows 1100 to 1200
# Processing rows 1200 to 1300
# Processing rows 1300 to 1400
# Processing rows 1400 to 1500
# Processing rows 1500 to 1600
# Processing rows 1600 to 1700
# Processing rows 1700 to 1800
# Processing rows 1800 to 1900
# Processing rows 1900 to 2000
# Processing rows 2000 to 2100
# Processing rows 2100 to 2200
# Processing rows 2200 to 2300
# Processing rows 2300 to 2400
# Processing rows 2400 to 2500
# Processing rows 2500 to 2600
# Processing rows 2600 to 2700
# Processing rows 2700 to 2800
# Processing rows 2800 to 2900
# Processing rows 2900 to 3000
# Processing rows 3000 to 3100
# Processing rows 3100 to 3200
# Processing rows 3200 to 3300
# Processing rows 3300 to 3400
# Processing rows 3400 to 3500
# Processing rows 3500 to 3600
# Processing rows 3600 to 3700
# Processing rows 3700 to 3800
# Processing rows 3800 to 3900
# Processing rows 3900 to 4000
# Processing rows 4000 to 4100
# Processing rows 4100 to 4200
# Processing rows 4200 to 4300
# Processing rows 4300 to 4400
# Processing rows 4400 to 4500
# Processing rows 4500 to 4600
# Processing rows 4600 to 4700
# Processing rows 4700 to 4800
# Processing rows 4800 to 4900
# Processing rows 4900 to 5000
# Processing rows 5000 to 5100
# Processing rows 5100 to 5200
# Processing rows 5200 to 5300
# Processing rows 5300 to 5400
# Processing rows 5400 to 5500
# Processing rows 5500 to 5600
# Processing rows 5600 to 5700
# Processing rows 5700 to 5800
# Processing rows 5800 to 5900
# Processing rows 5900 to 6000
# Processing rows 6000 to 6100
# Processing rows 6100 to 6200
# Processing rows 6200 to 6300
# Processing rows 6300 to 6400
# Processing rows 6400 to 6500
# Processing rows 6500 to 6600
# Processing rows 6600 to 6700
# Processing rows 6700 to 6800
# Processing rows 6800 to 6900
# Processing rows 6900 to 7000
# Processing rows 7000 to 7100
# Processing rows 7100 to 7200
# Processing rows 7200 to 7300
# Processing rows 7300 to 7400
# Processing rows 7400 to 7500
# Processing rows 7500 to 7600
# Processing rows 7600 to 7700
# Processing rows 7700 to 7800
# Processing rows 7800 to 7900
# Processing rows 7900 to 8000
# Processing rows 8000 to 8100
# Processing rows 8100 to 8200
# Processing rows 8200 to 8300
# Processing rows 8300 to 8400
# Processing rows 8400 to 8500
# Processing rows 8500 to 8600
# Processing rows 8600 to 8700
# Processing rows 8700 to 8800
# Processing rows 8800 to 8900
# Processing rows 8900 to 9000
# Processing rows 9000 to 9100
# Processing rows 9100 to 9200
# Processing rows 9200 to 9300
# Processing rows 9300 to 9400
# Processing rows 9400 to 9500
# Processing rows 9500 to 9600
# Processing rows 9600 to 9700
# Processing rows 9700 to 9800
# Processing rows 9800 to 9900
# Processing rows 9900 to 10000
# Processing rows 10000 to 10100
# Processing rows 10100 to 10200
# Processing rows 10200 to 10300
# Processing rows 10300 to 10400
# Processing rows 10400 to 10500
# Processing rows 10500 to 10600
# Processing rows 10600 to 10700
# Processing rows 10700 to 10800
# Processing rows 10800 to 10900
# Processing rows 10900 to 11000
# Processing rows 11000 to 11100
# Processing rows 11100 to 11200
# Processing rows 11200 to 11300
# Processing rows 11300 to 11400
# Processing rows 11400 to 11500

# %%
og['Coordinates_lat_lon'] = og['Coordinates'].apply(lambda x: (x.latitude, x.longitude) if x else None)

# %%
og.to_csv('../Data_Raw/project_tables/og_geocoded.csv', index=False)
